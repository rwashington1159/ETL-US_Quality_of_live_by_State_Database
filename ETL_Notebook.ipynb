# %% [markdown]
# # ETL Project
#
# Team Members
# - Harry Feldman
# - Jessica Pardo
# - Andrey Tokarev
# - Raven Washington

# %%
# Import Dependencies

import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import psycopg2

# Get the password from config file
from config import password

# %% [markdown]
# ## U.S. State Data
#
# - U.S. State Tables (CSV file). Data source: http://www.whypad.com/posts/excel-spreadsheet-of-us-states/583/
# - Quality Of Life by State (CSV file). Data source: https://worldpopulationreview.com/state-rankings/quality-of-life-by-state

# %% [markdown]
# ### Extraction

# %%
# File path
states_csv = 'Resources/Raw_data/us_states.csv'

# %%
# Read csv and store in to Pandas Dataframe
col_Names=["STATE", "state_name", "state_abr"]
states_df= pd.read_csv(states_csv,names=col_Names)
states_df.head()
# Out:
#         STATE  state_name state_abr
# 0     ALABAMA     Alabama        AL
# 1      ALASKA      Alaska        AK
# 2     ARIZONA     Arizona        AZ
# 3    ARKANSAS    Arkansas        AR
# 4  CALIFORNIA  California        CA

# %%
# File path
ranking_csv = 'Resources/Raw_data/state_ranking.csv'

# %%
# Read csv and store in to Pandas Dataframe
ranking_df = pd.read_csv(ranking_csv)
ranking_df.head()
# Out:
#            State  lifeQualityRank  healthCareRank  educationRank  economyRank
# 0     Washington                1               4              4            3
# 1  New Hampshire                2              16              5           13
# 2      Minnesota                3              10             17           18
# 3           Utah                4               9             10            2
# 4        Vermont                5              11              8           29

# %% [markdown]
# ### Transformation

# %%
states_df = states_df.drop(columns=['STATE'])
states_df.head()
# Out:
#    state_name state_abr
# 0     Alabama        AL
# 1      Alaska        AK
# 2     Arizona        AZ
# 3    Arkansas        AR
# 4  California        CA

# %%
ranking_df = ranking_df.rename(columns={'State':'state_name'})
ranking_df.head()
# Out:
#       state_name  lifeQualityRank  healthCareRank  educationRank  economyRank
# 0     Washington                1               4              4            3
# 1  New Hampshire                2              16              5           13
# 2      Minnesota                3              10             17           18
# 3           Utah                4               9             10            2
# 4        Vermont                5              11              8           29

# %%
state = pd.merge(left=states_df, right=ranking_df, how='left', left_on='state_name', right_on='state_name')
state.head()
# Out:
#    state_name state_abr  lifeQualityRank  healthCareRank  educationRank  \
# 0     Alabama        AL               49              46             50
# 1      Alaska        AK               44              25             47
# 2     Arizona        AZ               34              23             40
# 3    Arkansas        AR               45              49             42
# 4  California        CA               19               7             21
#
#    economyRank
# 0           45
# 1           46
# 2           10
# 3           43
# 4            4

# %%
state.index.names = ['state_id']
state.head()
# Out:
#           state_name state_abr  lifeQualityRank  healthCareRank  \
# state_id
# 0            Alabama        AL               49              46
# 1             Alaska        AK               44              25
# 2            Arizona        AZ               34              23
# 3           Arkansas        AR               45              49
# 4         California        CA               19               7
#
#           educationRank  economyRank
# state_id
# 0                    50           45
# 1                    47           46
# 2                    40           10
# 3                    42           43
# 4                    21            4

# %%
# Export Data
state.to_csv(r'Resources/Clean_data/state.csv')

# %% [markdown]
# ## Housing Data
#
# - Zillow Economics Data(CSV file). Data source: https://www.kaggle.com/zillow/zecon

# %% [markdown]
# ### Extraction

# %%
state_id_df = pd.read_csv("./Resources/Clean_data/state.csv")
state_id_df.head(3)
# Out:
#    state_id state_name state_abr  lifeQualityRank  healthCareRank  \
# 0         0    Alabama        AL               49              46
# 1         1     Alaska        AK               44              25
# 2         2    Arizona        AZ               34              23
#
#    educationRank  economyRank
# 0             50           45
# 1             47           46
# 2             40           10

# %%
housing_df = pd.read_csv("./Resources/Raw_data/State_time_series.csv")
housing_df.head(3)
# Out:
#          Date RegionName  DaysOnZillow_AllHomes  \
# 0  1996-04-30    Alabama                    NaN
# 1  1996-04-30    Arizona                    NaN
# 2  1996-04-30   Arkansas                    NaN
#
#    InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                    NaN
#
#    MedianListingPricePerSqft_1Bedroom  MedianListingPricePerSqft_2Bedroom  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
#
#    MedianListingPricePerSqft_3Bedroom  MedianListingPricePerSqft_4Bedroom  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
#
#    MedianListingPricePerSqft_5BedroomOrMore  ...  ZHVI_BottomTier  \
# 0                                       NaN  ...          45600.0
# 1                                       NaN  ...          67100.0
# 2                                       NaN  ...          38400.0
#
#    ZHVI_CondoCoop  ZHVI_MiddleTier  ZHVI_SingleFamilyResidence  ZHVI_TopTier  \
# 0         99500.0          79500.0                     79000.0      140200.0
# 1         78900.0         103600.0                    107500.0      168700.0
# 2         70300.0          64400.0                     64500.0      115200.0
#
#    ZRI_AllHomes  ZRI_AllHomesPlusMultifamily  ZriPerSqft_AllHomes  \
# 0           NaN                          NaN                  NaN
# 1           NaN                          NaN                  NaN
# 2           NaN                          NaN                  NaN
#
#    Zri_MultiFamilyResidenceRental  Zri_SingleFamilyResidenceRental
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
#
# [3 rows x 82 columns]

# %% [markdown]
# ### Transformation

# %%
clean_housing_df = housing_df[['Date','RegionName', 'MedianListingPricePerSqft_AllHomes', 'MedianRentalPricePerSqft_AllHomes', 
                               'PctOfHomesDecreasingInValues_AllHomes', 'PctOfHomesIncreasingInValues_AllHomes']]
clean_housing_df.head(3)
# Out:
#          Date RegionName  MedianListingPricePerSqft_AllHomes  \
# 0  1996-04-30    Alabama                                 NaN
# 1  1996-04-30    Arizona                                 NaN
# 2  1996-04-30   Arkansas                                 NaN
#
#    MedianRentalPricePerSqft_AllHomes  PctOfHomesDecreasingInValues_AllHomes  \
# 0                                NaN                                    NaN
# 1                                NaN                                    NaN
# 2                                NaN                                    NaN
#
#    PctOfHomesIncreasingInValues_AllHomes
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN

# %%
clean_housing_df = clean_housing_df.dropna()

# %%
# renaming columns according to the ERD

# state_id integer FK >- state.state_id
# date date
# MedianListingPricePerSqft_AllHomes integer
# MedianRentalPricePerSqft_AllHomes integer
# PctOfHomesDecreasingInValues_AllHomes float
# PctOfHomesIncreasingInValues_AllHomes float

clean_housing_df = clean_housing_df.rename(columns={"RegionName": "state_name", "Date": "date"})
clean_housing_df.head(3)
# Out:
#             date  state_name  MedianListingPricePerSqft_AllHomes  \
# 8231  2010-01-31     Georgia                           94.303797
# 8269  2010-01-31  Washington                          169.014085
# 8276  2010-02-28    Arkansas                           88.310580
#
#       MedianRentalPricePerSqft_AllHomes  \
# 8231                           0.715309
# 8269                           0.961538
# 8276                           0.606187
#
#       PctOfHomesDecreasingInValues_AllHomes  \
# 8231                                  67.15
# 8269                                  78.82
# 8276                                  40.91
#
#       PctOfHomesIncreasingInValues_AllHomes
# 8231                                  25.88
# 8269                                  14.58
# 8276                                  48.71

# %%
clean_housing_df_merged = clean_housing_df.merge(state_id_df, how='inner', on='state_name', suffixes = None, copy = False)
clean_housing_df_merged.head(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-f590e05ab6c6> in <module>
# ----> 1 clean_housing_df_merged = clean_housing_df.merge(state_id_df, how='inner', on='state_name', suffixes = None, copy = False)
#       2 clean_housing_df_merged.head(3)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7282         from pandas.core.reshape.merge import merge
#    7283
# -> 7284         return merge(
#    7285             self,
#    7286             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      86         validate=validate,
#      87     )
# ---> 88     return op.get_result()
#      89
#      90
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     644
#     645         ldata, rdata = self.left._data, self.right._data
# --> 646         lsuf, rsuf = self.suffixes
#     647
#     648         llabels, rlabels = _items_overlap_with_suffix(
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
clean_housing_df_merged.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c480a6c01d1c> in <module>
# ----> 1 clean_housing_df_merged.columns
#
# NameError: name 'clean_housing_df_merged' is not defined

# %%
housing_df_final = clean_housing_df_merged.drop(labels=['state_abr', 'state_name', 
                                                        'lifeQualityRank', 'healthCareRank',
                                                        'educationRank', 'economyRank'
                                                       ], axis=1)

# %%
housing_df_final.columns

# %%
housing_df_final.to_csv("./Resources/Clean_data/housing.csv", index = False)

# %% [markdown]
# ## Income Data
# - USA Income Levels by United States Census Bureau https://data.world/uscensusbureau/acs-2015-5-e-income/workspace/file?filename=USA_ZCTA.csv

# %% [markdown]
# ### Extraction

# %%
income_df = pd.read_csv("./Resources/Raw_Data/USA_All_States.csv")

# %% [markdown]
# ### Transformation

# %%
clean_income_df = income_df[['AreaName','B19001_001']]
clean_income_df = clean_income_df.dropna()

# %%
# Renaming columns according to ERD
# state_id integer FK >- state.state_id
# household_income float
# year integer

clean_income_df = clean_income_df.rename(columns={"AreaName": "state_name", "B19001_001": "household_income"})
clean_income_df.head(3)
# Out:
#   state_name  household_income
# 0    Alabama           1848325
# 1     Alaska            250969
# 2    Arizona           2412212

# %%
# adding "year" column
clean_income_df['year'] = 2015
clean_income_df.head(3)
# Out:
#   state_name  household_income  year
# 0    Alabama           1848325  2015
# 1     Alaska            250969  2015
# 2    Arizona           2412212  2015

# %%
# need to replace state_name with state_id column 
clean_income_df_merged = clean_income_df.merge(state_id_df, how='inner', on='state_name', suffixes = None, copy = False)
clean_income_df_merged.head(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-3c11c6a59ee7> in <module>
#       1 # need to replace state_name with state_id column
# ----> 2 clean_income_df_merged = clean_income_df.merge(state_id_df, how='inner', on='state_name', suffixes = None, copy = False)
#       3 clean_income_df_merged.head(3)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7282         from pandas.core.reshape.merge import merge
#    7283
# -> 7284         return merge(
#    7285             self,
#    7286             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      86         validate=validate,
#      87     )
# ---> 88     return op.get_result()
#      89
#      90
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     644
#     645         ldata, rdata = self.left._data, self.right._data
# --> 646         lsuf, rsuf = self.suffixes
#     647
#     648         llabels, rlabels = _items_overlap_with_suffix(
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
income_df_final = clean_income_df_merged.drop(labels=['state_abr', 'state_name', 
                                                        'lifeQualityRank', 'healthCareRank',
                                                        'educationRank', 'economyRank'
                                                       ], axis=1)

# %%
income_df_final.columns

# %%
income_df_final.to_csv("./Resources/Clean_data/income.csv", index = False)

# %% [markdown]
# ## Crime Data
# - US Crime rates by County
# https://www.kaggle.com/mikejohnsonjr/united-states-crime-rates-by-county

# %% [markdown]
# ### Extraction

# %%
crime_df = pd.read_csv("./Resources/Raw_data/crime_data_w_population_and_crime_rate.csv")
crime_df.head(3)
# Out:
#              county_name  crime_rate_per_100000  index  EDITION  PART  IDNO  \
# 0     St. Louis city, MO            1791.995377      1        1     4  1612
# 1  Crittenden County, AR            1754.914968      2        1     4   130
# 2   Alexander County, IL            1664.700485      3        1     4   604
#
#    CPOPARST  CPOPCRIM  AG_ARRST  AG_OFF  ...  RAPE  ROBBERY  AGASSLT  BURGLRY  \
# 0    318667    318667        15      15  ...   200     1778     3609     4995
# 1     50717     50717         4       4  ...    38      165      662     1482
# 2      8040      8040         2       2  ...     2        5      119       82
#
#    LARCENY  MVTHEFT  ARSON  population  FIPS_ST  FIPS_CTY
# 0    13791     3543    464      318416       29       510
# 1     1753      189     28       49746        5        35
# 2      184       12      2        7629       17         3
#
# [3 rows x 24 columns]

# %% [markdown]
# ### Transformation

# %%
crime_df[['county_name','state_abr']] = crime_df['county_name'].str.split(',',expand=True)
crime_df.head(3)
# Out:
#          county_name  crime_rate_per_100000  index  EDITION  PART  IDNO  \
# 0     St. Louis city            1791.995377      1        1     4  1612
# 1  Crittenden County            1754.914968      2        1     4   130
# 2   Alexander County            1664.700485      3        1     4   604
#
#    CPOPARST  CPOPCRIM  AG_ARRST  AG_OFF  ...  ROBBERY  AGASSLT  BURGLRY  \
# 0    318667    318667        15      15  ...     1778     3609     4995
# 1     50717     50717         4       4  ...      165      662     1482
# 2      8040      8040         2       2  ...        5      119       82
#
#    LARCENY  MVTHEFT  ARSON  population  FIPS_ST  FIPS_CTY  state_abr
# 0    13791     3543    464      318416       29       510         MO
# 1     1753      189     28       49746        5        35         AR
# 2      184       12      2        7629       17         3         IL
#
# [3 rows x 25 columns]

# %%
crime_df1 = crime_df.drop(labels=['index', 'EDITION', 'PART', 'IDNO'], axis=1)
crime_df1.head(3)
# Out:
#          county_name  crime_rate_per_100000  CPOPARST  CPOPCRIM  AG_ARRST  \
# 0     St. Louis city            1791.995377    318667    318667        15
# 1  Crittenden County            1754.914968     50717     50717         4
# 2   Alexander County            1664.700485      8040      8040         2
#
#    AG_OFF  COVIND  INDEX  MODINDX  MURDER  ...  ROBBERY  AGASSLT  BURGLRY  \
# 0      15   100.0   5706    22329     119  ...     1778     3609     4995
# 1       4   100.0    873     3424       8  ...      165      662     1482
# 2       2   100.0    127      278       1  ...        5      119       82
#
#    LARCENY  MVTHEFT  ARSON  population  FIPS_ST  FIPS_CTY  state_abr
# 0    13791     3543    464      318416       29       510         MO
# 1     1753      189     28       49746        5        35         AR
# 2      184       12      2        7629       17         3         IL
#
# [3 rows x 21 columns]

# %%
crime_df1['year'] = 2016
crime_df1.head(3)
# Out:
#          county_name  crime_rate_per_100000  CPOPARST  CPOPCRIM  AG_ARRST  \
# 0     St. Louis city            1791.995377    318667    318667        15
# 1  Crittenden County            1754.914968     50717     50717         4
# 2   Alexander County            1664.700485      8040      8040         2
#
#    AG_OFF  COVIND  INDEX  MODINDX  MURDER  ...  AGASSLT  BURGLRY  LARCENY  \
# 0      15   100.0   5706    22329     119  ...     3609     4995    13791
# 1       4   100.0    873     3424       8  ...      662     1482     1753
# 2       2   100.0    127      278       1  ...      119       82      184
#
#    MVTHEFT  ARSON  population  FIPS_ST  FIPS_CTY  state_abr  year
# 0     3543    464      318416       29       510         MO  2016
# 1      189     28       49746        5        35         AR  2016
# 2       12      2        7629       17         3         IL  2016
#
# [3 rows x 22 columns]

# %%
crime_df1.columns
# Out:
# Index(['county_name', 'crime_rate_per_100000', 'CPOPARST', 'CPOPCRIM',
#        'AG_ARRST', 'AG_OFF', 'COVIND', 'INDEX', 'MODINDX', 'MURDER', 'RAPE',
#        'ROBBERY', 'AGASSLT', 'BURGLRY', 'LARCENY', 'MVTHEFT', 'ARSON',
#        'population', 'FIPS_ST', 'FIPS_CTY', 'state_abr', 'year'],
#       dtype='object')

# %%
crime_df2 = crime_df1.groupby(['state_abr'])

# %%
crime_df_final = crime_df2.agg({
    'crime_rate_per_100000': 'mean',
    'CPOPARST': 'mean',
    'CPOPCRIM': 'mean',
    'AG_ARRST': 'mean',
    'AG_OFF': 'mean',
    'COVIND': 'mean',
    'INDEX': 'mean',
    'MODINDX': 'mean',
    'MURDER': 'mean',
    'RAPE': 'mean',
    'ROBBERY': 'mean',
    'AGASSLT': 'mean',
    'BURGLRY': 'mean',
    'LARCENY': 'mean',
    'MVTHEFT': 'mean',
    'ARSON': 'mean',
    'population': 'mean',
    'FIPS_ST': 'mean',
    'FIPS_CTY': 'mean',
    'year': 'mean'
}).reset_index()
crime_df_final.head(3)
# Out:
#   state_abr  crime_rate_per_100000      CPOPARST      CPOPCRIM  AG_ARRST  \
# 0        AK             289.320957  20258.956522  20157.260870  1.347826
# 1        AL             385.645691  71970.492537  71316.417910  6.492537
# 2        AR             334.750727  39321.746667  38579.933333  3.720000
#
#      AG_OFF      COVIND       INDEX      MODINDX    MURDER  ...    ROBBERY  \
# 0  1.434783  100.000000  147.913043   710.869565  0.913043  ...  25.695652
# 1  6.253731   95.955690  320.492537  2487.134328  5.089552  ...  74.447761
# 2  3.720000   97.768183  183.066667  1443.693333  2.306667  ...  30.693333
#
#       AGASSLT     BURGLRY      LARCENY     MVTHEFT      ARSON    population  \
# 0  102.217391   77.434783   580.260870   53.173913   5.913043  31224.565217
# 1  221.746269  700.417910  1641.029851  145.626866  15.298507  72145.104478
# 2  133.760000  430.666667   937.693333   75.360000   7.520000  39458.306667
#
#    FIPS_ST  FIPS_CTY  year
# 0        2     147.0  2016
# 1        1      67.0  2016
# 2        5      75.0  2016
#
# [3 rows x 21 columns]

# %%
# need to replace state_name with state_id column 
crime_df_final_merged = crime_df_final.merge(state_id_df, how='inner', on='state_abr', suffixes = None, copy = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-8a8b2c1849cb> in <module>
#       1 # need to replace state_name with state_id column
# ----> 2 crime_df_final_merged = crime_df_final.merge(state_id_df, how='inner', on='state_abr', suffixes = None, copy = False)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7282         from pandas.core.reshape.merge import merge
#    7283
# -> 7284         return merge(
#    7285             self,
#    7286             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      86         validate=validate,
#      87     )
# ---> 88     return op.get_result()
#      89
#      90
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     644
#     645         ldata, rdata = self.left._data, self.right._data
# --> 646         lsuf, rsuf = self.suffixes
#     647
#     648         llabels, rlabels = _items_overlap_with_suffix(
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
crime_df_final_v2 = crime_df_final_merged.drop(labels=['state_abr', 'state_name', 
                                                        'lifeQualityRank', 'healthCareRank',
                                                        'educationRank', 'economyRank'
                                                       ], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-6561e114c1bc> in <module>
# ----> 1 crime_df_final_v2 = crime_df_final_merged.drop(labels=['state_abr', 'state_name',
#       2                                                         'lifeQualityRank', 'healthCareRank',
#       3                                                         'educationRank', 'economyRank'
#       4                                                        ], axis=1)
#
# NameError: name 'crime_df_final_merged' is not defined

# %%
crime_df_final_v2.columns

# %%
crime_df_final_v2.to_csv("./Resources/Clean_data/crime.csv", index = False)

# %% [markdown]
# ## Public school data
# - Public School Data (CSV file) Data Source: https://www.kaggle.com/carlosaguayo/usa-public-schools

# %% [markdown]
# ### Extraction

# %%
# File path
school_csv = 'Resources/Raw_data/public_schools.csv'

# %%
# Read csv and store in to Pandas DataFrame
schools_df = pd.read_csv(school_csv)
schools_df.head()
# Out:
#            X          Y  OBJECTID        NCESID  \
# 0 -81.050895  29.022271      2002  120192008041
# 1 -92.507288  31.180659      2003  220129002344
# 2 -69.971880  43.908147      2004  230378023129
# 3 -89.542799  32.728496      2005  280252001118
# 4 -94.361775  39.364359      2006  291645000891
#
#                                  NAME             ADDRESS        CITY STATE  \
# 0                     SAMSULA ACADEMY    248 N SAMSULA DR  NEW SMYRNA    FL
# 1  CAROLINE DORMON JUNIOR HIGH SCHOOL  8906 HWY 165 SOUTH   WOODWORTH    LA
# 2    HARRIET BEECHER STOWE ELEMENTARY    44 MCKEEN STREET   BRUNSWICK    ME
# 3     LEAKE CENTRAL ELEMENTARY SCHOOL    603 HWY. 16 WEST    CARTHAGE    MS
# 4                       KEARNEY ELEM.     902 S JEFFERSON     KEARNEY    MO
#
#      ZIP           ZIP4  ...     VAL_METHOD                  VAL_DATE  \
# 0  32168           8762  ...        IMAGERY  2014-05-20T00:00:00.000Z
# 1  71485  NOT AVAILABLE  ...  IMAGERY/OTHER  2015-06-19T00:00:00.000Z
# 2   4011  NOT AVAILABLE  ...        IMAGERY  2014-05-07T00:00:00.000Z
# 3  39051  NOT AVAILABLE  ...  IMAGERY/OTHER  2010-07-06T00:00:00.000Z
# 4  64060           8518  ...  IMAGERY/OTHER  2016-07-18T00:00:00.000Z
#
#                                              WEBSITE  LEVEL_ ENROLLMENT  \
# 0  http://nces.ed.gov/GLOBALLOCATOR/sch_info_popu...       1        222
# 1  http://nces.ed.gov/GLOBALLOCATOR/sch_info_popu...       1        312
# 2  http://nces.ed.gov/GLOBALLOCATOR/sch_info_popu...       1        739
# 3  http://nces.ed.gov/GLOBALLOCATOR/sch_info_popu...       1       1159
# 4  http://nces.ed.gov/GLOBALLOCATOR/sch_info_popu...       1        274
#
#    ST_GRADE END_GRADE  DISTRICTID  FT_TEACHER     SHELTER_ID
# 0        KG        05     1201920          13  NOT AVAILABLE
# 1        PK        08     2201290          21  NOT AVAILABLE
# 2        02        05     2303780          52  NOT AVAILABLE
# 3        PK        05     2802520          63  NOT AVAILABLE
# 4        KG        05     2916450          22  NOT AVAILABLE
#
# [5 rows x 33 columns]

# %%
# File path
state_csv = 'Resources/Clean_data/state.csv'

# %%
# Read csv and store in to Pandas DataFrame
state_df = pd.read_csv(state_csv)
state_df.head()
# Out:
#    state_id  state_name state_abr  lifeQualityRank  healthCareRank  \
# 0         0     Alabama        AL               49              46
# 1         1      Alaska        AK               44              25
# 2         2     Arizona        AZ               34              23
# 3         3    Arkansas        AR               45              49
# 4         4  California        CA               19               7
#
#    educationRank  economyRank
# 0             50           45
# 1             47           46
# 2             40           10
# 3             42           43
# 4             21            4

# %% [markdown]
# ### Transformation

# %%
# Cleaning up the DataFrame
# Selecting the columns to be displayed
clean_schools_df = schools_df[['STATE', 'CITY', 'NAME', 'ADDRESS', 'ZIP', 'X', 'Y', 'DISTRICTID', 'ST_GRADE', 'END_GRADE']]
clean_schools_df
# Out:
#        STATE            CITY                                             NAME  \
# 0         FL      NEW SMYRNA                                  SAMSULA ACADEMY
# 1         LA       WOODWORTH               CAROLINE DORMON JUNIOR HIGH SCHOOL
# 2         ME       BRUNSWICK                 HARRIET BEECHER STOWE ELEMENTARY
# 3         MS        CARTHAGE                  LEAKE CENTRAL ELEMENTARY SCHOOL
# 4         MO         KEARNEY                                    KEARNEY ELEM.
# ...      ...             ...                                              ...
# 102365    MI         DETROIT  COVENANT HOUSE ACADEMY DETROIT - SOUTHWEST SITE
# 102366    MI  SOUTH ROCKWOOD                 FRED W. RITTER ELEMENTARY SCHOOL
# 102367    MS      DIBERVILLE                                  DIBERVILLE ELEM
# 102368    MO     KANSAS CITY                                   DAVIDSON ELEM.
# 102369    MO     SPRINGFIELD                            JUVENILE JUSTICE CTR.
#
#                           ADDRESS    ZIP          X          Y  DISTRICTID  \
# 0                248 N SAMSULA DR  32168 -81.050895  29.022271     1201920
# 1              8906 HWY 165 SOUTH  71485 -92.507288  31.180659     2201290
# 2                44 MCKEEN STREET   4011 -69.971880  43.908147     2303780
# 3                603 HWY. 16 WEST  39051 -89.542799  32.728496     2802520
# 4                 902 S JEFFERSON  64060 -94.361775  39.364359     2916450
# ...                           ...    ...        ...        ...         ...
# 102365               1450 25TH ST  48216 -83.085229  42.320632     2600322
# 102366  5650 CARLETON ROCKWOOD RD  48179 -83.272599  42.062038     2601980
# 102367           4540 BRODIE ROAD  39540 -88.914089  30.436478     2801770
# 102368            5100 N HIGHLAND  64118 -94.558365  39.187941     2922800
# 102369           1111 N ROBBERSON  65802 -93.291370  37.220353     2928860
#
#        ST_GRADE END_GRADE
# 0            KG        05
# 1            PK        08
# 2            02        05
# 3            PK        05
# 4            KG        05
# ...         ...       ...
# 102365       09        12
# 102366       KG        04
# 102367       KG        03
# 102368       PK        05
# 102369       07        12
#
# [102370 rows x 10 columns]

# %%
# Dropping null values
clean_schools_df = clean_schools_df.dropna()
clean_schools_df
# Out:
#        STATE            CITY                                             NAME  \
# 0         FL      NEW SMYRNA                                  SAMSULA ACADEMY
# 1         LA       WOODWORTH               CAROLINE DORMON JUNIOR HIGH SCHOOL
# 2         ME       BRUNSWICK                 HARRIET BEECHER STOWE ELEMENTARY
# 3         MS        CARTHAGE                  LEAKE CENTRAL ELEMENTARY SCHOOL
# 4         MO         KEARNEY                                    KEARNEY ELEM.
# ...      ...             ...                                              ...
# 102365    MI         DETROIT  COVENANT HOUSE ACADEMY DETROIT - SOUTHWEST SITE
# 102366    MI  SOUTH ROCKWOOD                 FRED W. RITTER ELEMENTARY SCHOOL
# 102367    MS      DIBERVILLE                                  DIBERVILLE ELEM
# 102368    MO     KANSAS CITY                                   DAVIDSON ELEM.
# 102369    MO     SPRINGFIELD                            JUVENILE JUSTICE CTR.
#
#                           ADDRESS    ZIP          X          Y  DISTRICTID  \
# 0                248 N SAMSULA DR  32168 -81.050895  29.022271     1201920
# 1              8906 HWY 165 SOUTH  71485 -92.507288  31.180659     2201290
# 2                44 MCKEEN STREET   4011 -69.971880  43.908147     2303780
# 3                603 HWY. 16 WEST  39051 -89.542799  32.728496     2802520
# 4                 902 S JEFFERSON  64060 -94.361775  39.364359     2916450
# ...                           ...    ...        ...        ...         ...
# 102365               1450 25TH ST  48216 -83.085229  42.320632     2600322
# 102366  5650 CARLETON ROCKWOOD RD  48179 -83.272599  42.062038     2601980
# 102367           4540 BRODIE ROAD  39540 -88.914089  30.436478     2801770
# 102368            5100 N HIGHLAND  64118 -94.558365  39.187941     2922800
# 102369           1111 N ROBBERSON  65802 -93.291370  37.220353     2928860
#
#        ST_GRADE END_GRADE
# 0            KG        05
# 1            PK        08
# 2            02        05
# 3            PK        05
# 4            KG        05
# ...         ...       ...
# 102365       09        12
# 102366       KG        04
# 102367       KG        03
# 102368       PK        05
# 102369       07        12
#
# [102368 rows x 10 columns]

# %%
# Renaiming Columns
clean_schools_df = clean_schools_df.rename(columns={'STATE':'state_abr', 'CITY':'City', 'NAME':'SchoolName', 'ADDRESS':'Address',
                                                    'ZIP':'Zip', 'DISTRICTID':'DistrictID', 'ST_GRADE':'StartGrade', 'END_GRADE':'EndGrade'})
clean_schools_df.head()
# Out:
#   state_abr        City                          SchoolName  \
# 0        FL  NEW SMYRNA                     SAMSULA ACADEMY
# 1        LA   WOODWORTH  CAROLINE DORMON JUNIOR HIGH SCHOOL
# 2        ME   BRUNSWICK    HARRIET BEECHER STOWE ELEMENTARY
# 3        MS    CARTHAGE     LEAKE CENTRAL ELEMENTARY SCHOOL
# 4        MO     KEARNEY                       KEARNEY ELEM.
#
#               Address    Zip          X          Y  DistrictID StartGrade  \
# 0    248 N SAMSULA DR  32168 -81.050895  29.022271     1201920         KG
# 1  8906 HWY 165 SOUTH  71485 -92.507288  31.180659     2201290         PK
# 2    44 MCKEEN STREET   4011 -69.971880  43.908147     2303780         02
# 3    603 HWY. 16 WEST  39051 -89.542799  32.728496     2802520         PK
# 4     902 S JEFFERSON  64060 -94.361775  39.364359     2916450         KG
#
#   EndGrade
# 0       05
# 1       08
# 2       05
# 3       05
# 4       05

# %%
# Merge table for state_id

public_schools_merge = pd.merge(left=state_df, right=clean_schools_df, how='right', left_on='state_abr', right_on='state_abr')
public_schools_merge.head()
# Out:
#    state_id state_name state_abr  lifeQualityRank  healthCareRank  \
# 0       0.0    Alabama        AL             49.0            46.0
# 1       0.0    Alabama        AL             49.0            46.0
# 2       0.0    Alabama        AL             49.0            46.0
# 3       0.0    Alabama        AL             49.0            46.0
# 4       0.0    Alabama        AL             49.0            46.0
#
#    educationRank  economyRank            City                  SchoolName  \
# 0           50.0         45.0           LEEDS              LEEDS HIGH SCH
# 1           50.0         45.0         CULLMAN        GOOD HOPE MIDDLE SCH
# 2           50.0         45.0    GUNTERSVILLE      BRINDLEE MT MIDDLE SCH
# 3           50.0         45.0  SMITHS STATION  SMITH STATION FRESHMAN CTR
# 4           50.0         45.0       CLEVELAND          CLEVELAND ELEM SCH
#
#                     Address    Zip          X          Y  DistrictID  \
# 0      1500 GREENWAVE DRIVE  35094 -86.535935  33.548162      100011
# 1  216 GOOD HOPE SCHOOL RD.  35057 -86.881057  34.102738      101020
# 2      1050 SCANT CITY ROAD  35976 -86.422337  34.377158      100006
# 3         1150 LEE ROAD 298  36877 -85.099268  32.536590      102070
# 4            115 STADIUM DR  35049 -86.572919  33.993417      100420
#
#   StartGrade EndGrade
# 0         09       12
# 1         06       08
# 2         06       08
# 3         09       09
# 4         KG       06

# %%
# Selecting the columns to be displayed
public_schools = public_schools_merge[['state_id', 'City', 'SchoolName', 'Address', 'Zip', 'X', 'Y', 'DistrictID', 'StartGrade', 'EndGrade']]
public_schools
# Out:
#         state_id            City                           SchoolName  \
# 0            0.0           LEEDS                       LEEDS HIGH SCH
# 1            0.0         CULLMAN                 GOOD HOPE MIDDLE SCH
# 2            0.0    GUNTERSVILLE               BRINDLEE MT MIDDLE SCH
# 3            0.0  SMITHS STATION           SMITH STATION FRESHMAN CTR
# 4            0.0       CLEVELAND                   CLEVELAND ELEM SCH
# ...          ...             ...                                  ...
# 102363       NaN    SAINT THOMAS       JOSEPH GOMEZ ELEMENTARY SCHOOL
# 102364       NaN      SAINT JOHN                     JULIUS E SPRAUVE
# 102365       NaN    SAINT THOMAS      LEONARD DOBER ELEMENTARY SCHOOL
# 102366       NaN     SAINT CROIX  RICARDO RICHARDS ELEMENTARY SCCHOOL
# 102367       NaN    SAINT THOMAS           LOCKHART ELEMENTARY SCHOOL
#
#                           Address    Zip          X          Y  DistrictID  \
# 0            1500 GREENWAVE DRIVE  35094 -86.535935  33.548162      100011
# 1        216 GOOD HOPE SCHOOL RD.  35057 -86.881057  34.102738      101020
# 2            1050 SCANT CITY ROAD  35976 -86.422337  34.377158      100006
# 3               1150 LEE ROAD 298  36877 -85.099268  32.536590      102070
# 4                  115 STADIUM DR  35049 -86.572919  33.993417      100420
# ...                           ...    ...        ...        ...         ...
# 102363          142 ANNAS RETREAT    802 -64.919936  18.338171     7800030
# 102364       14 18 ESTATE ENIGHED    831 -64.793916  18.330464     7800030
# 102365  9A 10B KRONPRINDSENS GADE    802 -64.925850  18.342520     7800030
# 102366            491 BARREN SPOT    850 -64.760782  17.725168     7800002
# 102367           41 ESTATE THOMAS    802 -64.917602  18.341950     7800030
#
#        StartGrade EndGrade
# 0              09       12
# 1              06       08
# 2              06       08
# 3              09       09
# 4              KG       06
# ...           ...      ...
# 102363         KG       06
# 102364         KG       08
# 102365         04       06
# 102366         KG       06
# 102367         KG       06
#
# [102368 rows x 10 columns]

# %%
# Dropping null values
public_schools = public_schools.dropna()
public_schools
# Out:
#         state_id            City                  SchoolName  \
# 0            0.0           LEEDS              LEEDS HIGH SCH
# 1            0.0         CULLMAN        GOOD HOPE MIDDLE SCH
# 2            0.0    GUNTERSVILLE      BRINDLEE MT MIDDLE SCH
# 3            0.0  SMITHS STATION  SMITH STATION FRESHMAN CTR
# 4            0.0       CLEVELAND          CLEVELAND ELEM SCH
# ...          ...             ...                         ...
# 100614      49.0        EVANSTON  HORIZON ALTERNATIVE SCHOOL
# 100615      49.0        CHEYENNE         ANDERSON ELEMENTARY
# 100616      49.0        EVANSTON         DAVIS MIDDLE SCHOOL
# 100617      49.0        SHERIDAN               FT. MACKENZIE
# 100618      49.0    POWDER RIVER     POWDER RIVER ELEMENTARY
#
#                          Address    Zip           X          Y  DistrictID  \
# 0           1500 GREENWAVE DRIVE  35094  -86.535935  33.548162      100011
# 1       216 GOOD HOPE SCHOOL RD.  35057  -86.881057  34.102738      101020
# 2           1050 SCANT CITY ROAD  35976  -86.422337  34.377158      100006
# 3              1150 LEE ROAD 298  36877  -85.099268  32.536590      102070
# 4                 115 STADIUM DR  35049  -86.572919  33.993417      100420
# ...                          ...    ...         ...        ...         ...
# 100614        164 YELLOWCREEK RD  82931 -110.980300  41.259840     5602760
# 100615        2204 PLAIN VIEW RD  82009 -104.786858  41.170001     5601980
# 100616            837 NO NAME ST  82931 -110.972237  41.260919     5602760
# 100617              620 LEWIS ST  82801 -106.965030  44.803526     5605695
# 100618          35462 NOTCHES RD  82648 -106.988950  43.036013     5604510
#
#        StartGrade EndGrade
# 0              09       12
# 1              06       08
# 2              06       08
# 3              09       09
# 4              KG       06
# ...           ...      ...
# 100614         07       12
# 100615         KG       06
# 100616         06       08
# 100617         09       12
# 100618         KG       06
#
# [100619 rows x 10 columns]

# %%
# Export Data
public_schools.to_csv(r'Resources/Clean_data/public_schools.csv', index = False)

# %% [markdown]
# ## Unemployment Data
# - USA Unemployment rate Dataset (CSV file) Data Source: https://www.kaggle.com/carlosaguayo/2018-unemployment-rate-by-county/version/1

# %% [markdown]
# ### Extraction

# %%
# Grab unemployment csv
unemployment_df = pd.read_csv("./Resources/Raw_data/GeoFRED_Unemployment_Rate_by_County_Percent.csv")
unemployment_df.head()
# Out:
#     Series ID           Region Name  Region Code  2000  2001  2002  2003  \
# 0  SCABBE1URN  Abbeville County, SC        45001   3.8   6.6   7.7   9.1
# 1  LAACAD0URN     Acadia Parish, LA        22001   5.8   6.0   6.3   6.8
# 2  VAACCO1URN   Accomack County, VA        51001   3.0   3.4   4.2   4.4
# 3  IDADAC1URN        Ada County, ID        16001   3.4   3.9   4.7   4.9
# 4  OKADAI1URN      Adair County, OK        40001   3.5   4.1   4.8   7.8
#
#    2004  2005  2006  ...  2009  2010  2011  2012  2013  2014  2015  2016  \
# 0   8.2   7.7   8.8  ...  14.2  13.6  12.5  10.6   9.5   7.7   6.9   5.5
# 1   5.8   6.1   3.6  ...   6.5   7.3   6.7   6.0   6.0   5.8   6.9   7.4
# 2   4.7   4.7   4.3  ...   6.5   7.9   8.4   7.9   7.2   6.7   5.5   5.0
# 3   4.1   3.3   2.7  ...   8.9   8.3   7.3   6.2   5.2   4.2   3.7   3.3
# 4   6.2   4.8   4.4  ...   8.0  10.5   9.2   9.1   9.8   8.0   6.1   5.9
#
#    2017  2018
# 0   4.6   4.2
# 1   5.9   5.4
# 2   4.9   4.1
# 3   2.8   2.4
# 4   5.0   4.4
#
# [5 rows x 22 columns]

# %%
# Extract State into its own column
unemployment_df[['Region Name','State']] = unemployment_df['Region Name'].str.split(',',expand=True)
unemployment_df.head()
# Out:
#     Series ID       Region Name  Region Code  2000  2001  2002  2003  2004  \
# 0  SCABBE1URN  Abbeville County        45001   3.8   6.6   7.7   9.1   8.2
# 1  LAACAD0URN     Acadia Parish        22001   5.8   6.0   6.3   6.8   5.8
# 2  VAACCO1URN   Accomack County        51001   3.0   3.4   4.2   4.4   4.7
# 3  IDADAC1URN        Ada County        16001   3.4   3.9   4.7   4.9   4.1
# 4  OKADAI1URN      Adair County        40001   3.5   4.1   4.8   7.8   6.2
#
#    2005  2006  ...  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# 0   7.7   8.8  ...  13.6  12.5  10.6   9.5   7.7   6.9   5.5   4.6   4.2
# 1   6.1   3.6  ...   7.3   6.7   6.0   6.0   5.8   6.9   7.4   5.9   5.4
# 2   4.7   4.3  ...   7.9   8.4   7.9   7.2   6.7   5.5   5.0   4.9   4.1
# 3   3.3   2.7  ...   8.3   7.3   6.2   5.2   4.2   3.7   3.3   2.8   2.4
# 4   4.8   4.4  ...  10.5   9.2   9.1   9.8   8.0   6.1   5.9   5.0   4.4
#
#    State
# 0     SC
# 1     LA
# 2     VA
# 3     ID
# 4     OK
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Transformation

# %%
# Clean up and reorganize

# Extract desired data only
unemployment_df1 = unemployment_df.drop(labels=['Series ID'], axis=1)
unemployment_df = unemployment_df[['State', 'Region Name', 'Region Code'] + [str(x) for x in range(2000, 2019)]]

# Reorganize years
unemployment_df = unemployment_df.melt(('State', 'Region Name', 'Region Code'), var_name='Year', value_name='Unemployment')
unemployment_df.head()
# Out:
#   State       Region Name  Region Code  Year  Unemployment
# 0    SC  Abbeville County        45001  2000           3.8
# 1    LA     Acadia Parish        22001  2000           5.8
# 2    VA   Accomack County        51001  2000           3.0
# 3    ID        Ada County        16001  2000           3.4
# 4    OK      Adair County        40001  2000           3.5

# %%
# Further normalize data. There should be a Region name-Region code table
regions = {'Code': [], 'Name': []}
for index, row in unemployment_df.iterrows():
    code = row['Region Code']
    if code in regions['Code']:
        continue
    regions['Code'].append(code)
    regions['Name'].append(row['Region Name'])
code_df = pd.DataFrame(regions)
code_df.head()
# Out:
#     Code              Name
# 0  45001  Abbeville County
# 1  22001     Acadia Parish
# 2  51001   Accomack County
# 3  16001        Ada County
# 4  40001      Adair County

# %%
# Delete Region Name column from the unemployment to avoid redunancy
del unemployment_df['Region Name']

# %%
# Join with state ID table
states = pd.read_csv('Resources/Clean_data/state.csv')


# Fix formatting
unemployment_df['State'] = unemployment_df['State'].apply(lambda x: x[1:])


unemployment_df = pd.merge(unemployment_df,
                 states, left_on='State',
                 right_on='state_abr',
                 how='inner')\
                [['state_id', 'Region Code', 'Year', 'Unemployment']]

# %%
code_df.head()
# Out:
#     Code              Name
# 0  45001  Abbeville County
# 1  22001     Acadia Parish
# 2  51001   Accomack County
# 3  16001        Ada County
# 4  40001      Adair County

# %%
# Save data
unemployment_df.to_csv('Resources/Clean_data/unemployment.csv')
code_df.to_csv('Resources/Clean_data/region_codes.csv')

# %% [markdown]
# ## Load

# %%
# Create engine and connection to  db.

engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/US_quality_db')
connection = engine.connect()

# %% [markdown]
# - Postgresql Database table state

# %%
state_df.to_sql(name='state', con=engine, if_exists='append', index=False)

# %% [markdown]
# - Postgresql Database table Public School

# %%
public_schools.to_sql(name='public_schools', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## SQL Query

# %%
# Query the states from the state table into a Pandas dataframe
states_sql = pd.read_sql("SELECT * FROM state", connection)

# Displaying DF
states_sql.head()
# Out:
#    state_id state_abr  state_name  lifeQualityRank  healthCareRank  \
# 0         0        AL     Alabama               49              46
# 1         1        AK      Alaska               44              25
# 2         2        AZ     Arizona               34              23
# 3         3        AR    Arkansas               45              49
# 4         4        CA  California               19               7
#
#    educationRank  economyRank
# 0             50           45
# 1             47           46
# 2             40           10
# 3             42           43
# 4             21            4

# %%
connection.close()
