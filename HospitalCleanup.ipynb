# %% [markdown]
# # Hospital cleanup
# We already scraped the google maps ratings and did some pre-cleanup on the hospital data in the scrapeRatings.ipynb notebook. Now we just need to finalize the data for our database

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base

# %%
df = pd.read_csv('Resources/hospitalRatings.csv')
del df['Unnamed: 0']
df.head()
# Out:
#                                                 NAME  \
# 0  HOUSTON METHODIST SAN JACINTO HOSPITAL ALEXAND...
# 1                              WOODS AT PARKSIDE,THE
# 2                         DAYTON CHILDREN'S HOSPITAL
# 3                  VIBRA HOSPITAL OF MAHONING VALLEY
# 4             HAVEN BEHAVIORAL SENIOR CARE OF DAYTON
#
#                           ADDRESS      CITY STATE    ZIP        OWNER   BEDS  \
# 0          1700 JAMES BOWIE DRIVE   BAYTOWN    TX  77520   NON-PROFIT  182.0
# 1          349 OLDE RIDENOUR ROAD  COLUMBUS    OH  43230  PROPRIETARY   50.0
# 2             ONE CHILDRENS PLAZA    DAYTON    OH  45404   NON-PROFIT  155.0
# 3               8049 SOUTH AVENUE  BOARDMAN    OH  44512  PROPRIETARY   45.0
# 4  ONE ELIZABETH PLACE,E3 SUITE A    DAYTON    OH  45417  PROPRIETARY   32.0
#
#    RATING
# 0     4.5
# 1     4.1
# 2     4.0
# 3     4.6
# 4     2.5

# %%
# Looks like we're missing the website column. I must have deleted it by mistake in the original cleanup
# Let's grab it from the original data
hosp = pd.read_csv('Resources/Hospitals.csv')
hosp.head()
# Out:
#            X          Y  OBJECTID         ID  \
# 0 -94.945477  29.747620      8497   76777520
# 1 -82.881843  40.027143      8498  129043230
# 2 -84.168027  39.774242      8499  130045404
# 3 -80.632972  41.005169      8500  128844512
# 4 -84.199398  39.747740      8501  129845417
#
#                                                 NAME  \
# 0  HOUSTON METHODIST SAN JACINTO HOSPITAL ALEXAND...
# 1                              WOODS AT PARKSIDE,THE
# 2                         DAYTON CHILDREN'S HOSPITAL
# 3                  VIBRA HOSPITAL OF MAHONING VALLEY
# 4             HAVEN BEHAVIORAL SENIOR CARE OF DAYTON
#
#                           ADDRESS      CITY STATE    ZIP           ZIP4  ...  \
# 0          1700 JAMES BOWIE DRIVE   BAYTOWN    TX  77520  NOT AVAILABLE  ...
# 1          349 OLDE RIDENOUR ROAD  COLUMBUS    OH  43230  NOT AVAILABLE  ...
# 2             ONE CHILDRENS PLAZA    DAYTON    OH  45404  NOT AVAILABLE  ...
# 3               8049 SOUTH AVENUE  BOARDMAN    OH  44512  NOT AVAILABLE  ...
# 4  ONE ELIZABETH PLACE,E3 SUITE A    DAYTON    OH  45417  NOT AVAILABLE  ...
#
#                    VAL_DATE  \
# 0  2017-12-18T00:00:00.000Z
# 1  2018-04-26T00:00:00.000Z
# 2  2018-04-26T00:00:00.000Z
# 3  2018-04-26T00:00:00.000Z
# 4  2018-04-26T00:00:00.000Z
#
#                                              WEBSITE       STATE_ID  \
# 0  http://www.houstonmethodist.org/locations/san-...  NOT AVAILABLE
# 1                 http://www.thewoodsatparkside.com/           1815
# 2  http://www.childrensdayton.org/cms/home/index....           1411
# 3             http://www.mahoningvalleyhospital.com/           1428
# 4                https://dayton.havenbehavioral.com/           1506
#
#                                    ALT_NAME ST_FIPS        OWNER TTL_STAFF  \
# 0                             NOT AVAILABLE    48.0   NON-PROFIT    -999.0
# 1                             NOT AVAILABLE    39.0  PROPRIETARY    -999.0
# 2                             NOT AVAILABLE    39.0   NON-PROFIT    -999.0
# 3  MAHONING VALLEY HOSPITAL BOARDMAN CAMPUS    39.0  PROPRIETARY    -999.0
# 4                             NOT AVAILABLE    39.0  PROPRIETARY    -999.0
#
#     BEDS              TRAUMA        HELIPAD
# 0  182.0       NOT AVAILABLE              Y
# 1   50.0       NOT AVAILABLE  NOT AVAILABLE
# 2  155.0  PEDIATRIC LEVEL II              Y
# 3   45.0       NOT AVAILABLE  NOT AVAILABLE
# 4   32.0       NOT AVAILABLE  NOT AVAILABLE
#
# [5 rows x 34 columns]

# %%
df = pd.merge(df, hosp[['NAME', 'WEBSITE']], on='NAME')
df.head()
# Out:
#                                                 NAME  \
# 0  HOUSTON METHODIST SAN JACINTO HOSPITAL ALEXAND...
# 1                              WOODS AT PARKSIDE,THE
# 2                         DAYTON CHILDREN'S HOSPITAL
# 3                  VIBRA HOSPITAL OF MAHONING VALLEY
# 4             HAVEN BEHAVIORAL SENIOR CARE OF DAYTON
#
#                           ADDRESS      CITY STATE    ZIP        OWNER   BEDS  \
# 0          1700 JAMES BOWIE DRIVE   BAYTOWN    TX  77520   NON-PROFIT  182.0
# 1          349 OLDE RIDENOUR ROAD  COLUMBUS    OH  43230  PROPRIETARY   50.0
# 2             ONE CHILDRENS PLAZA    DAYTON    OH  45404   NON-PROFIT  155.0
# 3               8049 SOUTH AVENUE  BOARDMAN    OH  44512  PROPRIETARY   45.0
# 4  ONE ELIZABETH PLACE,E3 SUITE A    DAYTON    OH  45417  PROPRIETARY   32.0
#
#    RATING                                            WEBSITE
# 0     4.5  http://www.houstonmethodist.org/locations/san-...
# 1     4.1                 http://www.thewoodsatparkside.com/
# 2     4.0  http://www.childrensdayton.org/cms/home/index....
# 3     4.6             http://www.mahoningvalleyhospital.com/
# 4     2.5                https://dayton.havenbehavioral.com/

# %%
# Join with state_id table
states = pd.read_csv('Resources/Clean_data/state.csv')
df = pd.merge(df, states[['state_id', 'state_abr']], left_on='STATE', right_on = 'state_abr')[['state_id', 'NAME', 'ADDRESS', 'CITY', 'ZIP', 'OWNER', 'BEDS', 'RATING', 'WEBSITE']]
df
# Out:
#       state_id                                               NAME  \
# 0           42  HOUSTON METHODIST SAN JACINTO HOSPITAL ALEXAND...
# 1           42           PROVIDENCE HOSPITAL OF NORTH HOUSTON LLC
# 2           42                            MCCALLEN MEDICAL CENTER
# 3           42                           FAITH COMMUNITY HOSPITAL
# 4           42                           FAITH COMMUNITY HOSPITAL
# ...        ...                                                ...
# 8403         7                                    ROCKFORD CENTER
# 8404         7            SELECT SPECIALTY HOSPITAL OF WILMINGTON
# 8405         7                               BEEBE MEDICAL CENTER
# 8406         7                    BAYHEALTH KENT GENERAL HOSPITAL
# 8407         7                     DOVER BEHAVIORAL HEALTH SYSTEM
#
#                      ADDRESS        CITY    ZIP        OWNER   BEDS  RATING  \
# 0     1700 JAMES BOWIE DRIVE     BAYTOWN  77520   NON-PROFIT  182.0     4.5
# 1           16750 RED OAK DR     HOUSTON  77090  PROPRIETARY   16.0     4.0
# 2     301 WEST EXPRESSWAY 83     MCALLEN  78503  PROPRIETARY  441.0     4.0
# 3         215 CHISHOLM TRAIL   JACKSBORO  76458  PROPRIETARY   17.0     3.6
# 4         215 CHISHOLM TRAIL   JACKSBORO  76458  PROPRIETARY   17.0     3.6
# ...                      ...         ...    ...          ...    ...     ...
# 8403         100 ROCKFORD DR      NEWARK  19713  PROPRIETARY   92.0     2.0
# 8404        701 N CLAYTON ST  WILMINGTON  19805  PROPRIETARY   35.0     4.2
# 8405         424 SAVANNAH RD       LEWES  19958   NON-PROFIT  210.0     2.8
# 8406          640 S STATE ST       DOVER  19901   NON-PROFIT  236.0     2.6
# 8407        725 HORSEPOND RD       DOVER  19901  PROPRIETARY   52.0     1.8
#
#                                                 WEBSITE
# 0     http://www.houstonmethodist.org/locations/san-...
# 1                                      http://phnh.net/
# 2                  http://www.mcallenmedicalcenter.com/
# 3                              https://www.fchtexas.com
# 4                 http://www.faithcommunityhospital.com
# ...                                                 ...
# 8403                     http://www.rockfordcenter.com/
# 8404    http://wilmington.selectspecialtyhospitals.com/
# 8405                  http://www.beebemed.org/index.cfm
# 8406  http://www.bayhealth.org/Home/Facilities/tabid...
# 8407                    http://www.doverbehavioral.com/
#
# [8408 rows x 9 columns]

# %%
# Save data
df.to_csv('Resources/Clean_data/hospitals.csv')

# %%
# Connect to database
from secrets import username, password
Base = automap_base()
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/ETL')
conn = engine.connect()
Base.prepare(engine, reflect= True)
Row = Base.classes.hospitals

# %%
# Insert into database
rows = []
columns = df.columns
for index, row in df.iterrows():
    object = Row(
    state_id= row['state_id'],
    name= row['NAME'],
    address= row['ADDRESS'],
    city= row['CITY'],
    zip= row['ZIP'],
    owner= row['OWNER'],
    rating= row['RATING'],
    website= row['WEBSITE']
    )
    rows.append(object)

# %%
# Commit changes
sesh = Session(engine)
sesh.add_all(rows)
sesh.commit()
sesh.close()
