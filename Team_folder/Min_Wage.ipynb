# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base
import psycopg2

# %%
#Path
min_wage_df = "min_wage.csv"

# %%
#Read csv
min_wage_df = pd.read_csv("min_wage.csv")
min_wage_df
# Out:
#       state_id  Year     state_name  min_wage
# 0            0  1968        Alabama      8.55
# 1            1  1968         Alaska     15.61
# 2            2  1968        Arizona      8.55
# 3            3  1968       Arkansas      8.55
# 4            4  1968     California     12.26
# ...        ...   ...            ...       ...
# 2857      2857  2020       Virginia      7.25
# 2858      2858  2020     Washington     13.50
# 2859      2859  2020  West Virginia      8.75
# 2860      2860  2020      Wisconsin      7.25
# 2861      2861  2020        Wyoming      7.25
#
# [2862 rows x 4 columns]

# %%
del min_wage_df['state_id']

# %%
min_wage_df
# Out:
#       Year     state_name  min_wage
# 0     1968        Alabama      8.55
# 1     1968         Alaska     15.61
# 2     1968        Arizona      8.55
# 3     1968       Arkansas      8.55
# 4     1968     California     12.26
# ...    ...            ...       ...
# 2857  2020       Virginia      7.25
# 2858  2020     Washington     13.50
# 2859  2020  West Virginia      8.75
# 2860  2020      Wisconsin      7.25
# 2861  2020        Wyoming      7.25
#
# [2862 rows x 3 columns]

# %%
#Read state csv
states_df = pd.read_csv("state.csv")
states_df
# Out:
#     state_id      state_name state_abr  lifeQualityRank  healthCareRank  \
# 0          0         Alabama        AL               49              46
# 1          1          Alaska        AK               44              25
# 2          2         Arizona        AZ               34              23
# 3          3        Arkansas        AR               45              49
# 4          4      California        CA               19               7
# 5          5        Colorado        CO               10              12
# 6          6     Connecticut        CT               21               3
# 7          7        Delaware        DE               23              15
# 8          8         Florida        FL               13              29
# 9          9         Georgia        GA               17              39
# 10        10          Hawaii        HI               24               1
# 11        11           Idaho        ID               16              26
# ...

# %%
states_df1.head()
# Out:
#    state_name state_abr  lifeQualityRank  healthCareRank  educationRank  \
# 0     Alabama        AL               49              46             50
# 1      Alaska        AK               44              25             47
# 2     Arizona        AZ               34              23             40
# 3    Arkansas        AR               45              49             42
# 4  California        CA               19               7             21
#
#    economyRank
# 0           45
# 1           46
# 2           10
# 3           43
# 4            4

# %%
merged_states_df = pd.merge(states_df, min_wage_df, on='state_name', how='inner')

# %%
merged_states_df
# Out:
#       state_id state_name state_abr  lifeQualityRank  healthCareRank  \
# 0            0    Alabama        AL               49              46
# 1            0    Alabama        AL               49              46
# 2            0    Alabama        AL               49              46
# 3            0    Alabama        AL               49              46
# 4            0    Alabama        AL               49              46
# ...        ...        ...       ...              ...             ...
# 2645        49    Wyoming        WY               31              42
# 2646        49    Wyoming        WY               31              42
# 2647        49    Wyoming        WY               31              42
# 2648        49    Wyoming        WY               31              42
# 2649        49    Wyoming        WY               31              42
#
#       educationRank  economyRank  Year  min_wage
# 0                50           45  1968      8.55
# ...

# %%
min_wage_df= merged_states_df[['state_id', 'Year', 'min_wage']]
min_wage_df
# Out:
#       state_id  Year  min_wage
# 0            0  1968      8.55
# 1            0  1969      8.11
# 2            0  1970      8.67
# 3            0  1971      8.30
# 4            0  1972      9.90
# ...        ...   ...       ...
# 2645        49  2016      7.81
# 2646        49  2017      7.65
# 2647        49  2018      7.47
# 2648        49  2019      7.34
# 2649        49  2020      7.25
#
# [2650 rows x 3 columns]

# %%
min_wage.to_csv('min_wage.csv')

# %%
min_wage.columns
# Out:
# Index(['Year', 'state_name', 'min_wage'], dtype='object')

# %%
engine = create_engine(f'postgresql://postgres:Intentional2021@localhost:5432/min_wage')
connection = engine.connect()

# %%
states_df.to_sql(name="state", con=engine, if_exists="append", index=False)

# %%
min_wage_df.to_sql(name="min_wage", con=engine, if_exists="append", index=False)
